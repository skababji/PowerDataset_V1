# %%
import sys
sys.path.insert(0, '../')

from src.power.gen_scen_fnctns import *

# %%
import datetime
import os
import pandapower.networks as nw
import pandas as pd
import numpy as np
import pandapower.plotting as plot
import pandapower as pp

# %% [markdown]
# ## Select your base Power Grid from Pandapower for your research
# <span style="color:red">(Note: Power grid shall match the one used to generate the measurements template)</span>

# %%
net=nw.case118() #Select Power grid here

# %% [markdown]
# ## Select Parameters

# %%
input_params = {
    'set_id': 'A', # Enter prefix for scenario id (Note: Prefix enables you to combine runs easily)
    'n_clean_scenarios':500,  # Enter No. of load scenarios
    'noise_per_clean': 10,  # Enter No. of noisy scenarios per clean scenaios. No of overall generated examples will be n_clean_scenarios x noise_per_clean
    'inst_error':0.02, # Enter value to be used for all meas except voltage magnitudes whereas inst error will be 0.5 x inst_error
    'noise_on_meas': 'gaussian' #noise imposed on measurments to generate noisy scenarios either gaussian or uniform. In both cases, inst_error std dev is used
}

# %% [markdown]
# #### Construct Paths

# %%
runs_path = '../runs/'

currentDT = datetime.datetime.now()
trial = 'Power_' + input_params['set_id'] + '_' + str(currentDT.year) + str(currentDT.month) + str(
    currentDT.day) + str(
    currentDT.hour) + str(currentDT.minute)


if not os.path.exists(runs_path + trial):
    os.makedirs(runs_path + trial)
trial_path = runs_path + trial + "/"

if not os.path.exists(runs_path + trial + '/grid'):
    os.makedirs(runs_path + trial + '/grid')
grid_path = runs_path + trial + "/grid/"


if not os.path.exists(runs_path + trial + '/datasets'):
    os.makedirs(runs_path + trial + '/datasets')
datasets_path = runs_path + trial + "/datasets/"

if not os.path.exists(runs_path + trial + '/base_net'):
    os.makedirs(runs_path + trial + '/base_net')
base_net_path = runs_path + trial + '/base_net/'

# %%
net_label='case'+str(len(net.bus))
n_bus = len(net.bus)
slack=net.ext_grid.bus.item()
inst_err=input_params['inst_error']

# %%
"""Run AC power flow analysis for base network"""
pp.runpp(net)

# %% [markdown]
# #### Construct Measurements

# %%
h4all = gen_h4all(net)

# %%
all_meas = pd.read_csv('../runs/meas_template.csv')#Template shall correspond to grid. Manually construct the template if necessary.

# %%
"""Construct measurments for base network based on meas template"""
h,h_reordered, h_no_slack=gen_meas(net, all_meas, h4all, base_net_path, inst_err=input_params['inst_error'])
n_meas=len(h)
# Out:
# Generating measurements for net..
# Done!

# %% [markdown]
# #### Save Base Grid Info

# %%
""" Save base network information"""
net.bus.to_csv(grid_path + 'grid_bus.csv')
net.line.to_csv(grid_path + 'grid_line.csv')
net.trafo.to_csv(grid_path + 'grid_trafo.csv')
net.trafo3w.to_csv(grid_path + 'grid_trafo3w.csv')
net.gen.to_csv(grid_path + 'grid_gen.csv')
net.load.to_csv(grid_path + 'grid_load.csv')

"""Plot base network"""
# simple plot of net with existing geocoordinates or generated artificial geocoordinates
net_ax=plot.simple_plot(net, show_plot=False)
net_fig=net_ax.get_figure()
net_fig.savefig(grid_path+'grid_plot.png')

# %% [markdown]
# ## Generate Duplicated Clean Scenarios

# %%
""" Generate Clean Scenarios"""
clean_scenarios_ids,clean_scenarios=gen_clean_scen_unfrm(net, input_params['n_clean_scenarios'],input_params['set_id']) #clean_scenario which fails to converge using runpp will NOT be counted
dplct_ids, dplct_clean_scenarios = duplicate_scenarios(clean_scenarios_ids,clean_scenarios, input_params['noise_per_clean']) #this will creat new duplicate objects (i.e. nets) using deep copy
# Out:
# gen_clean_scen_unfrm: Generating BASE CLEAN scenario 0 ...
#
#
# Generating CLEAN scenario No.   1...
# Running Power Flow Analysis for net   1
# Updating measurements of net   1
# Generating CLEAN scenario No.   2...
# Running Power Flow Analysis for net   2
# Updating measurements of net   2
# Generating CLEAN scenario No.   3...
# Running Power Flow Analysis for net   3
# Updating measurements of net   3
# Generating CLEAN scenario No.   4...
# Running Power Flow Analysis for net   4
# Updating measurements of net   4
# Generating CLEAN scenario No.   5...
# Running Power Flow Analysis for net   5
# Updating measurements of net   5
# Generating CLEAN scenario No.   6...
# Running Power Flow Analysis for net   6
# Updating measurements of net   6
# Generating CLEAN scenario No.   7...
# Running Power Flow Analysis for net   7
# Updating measurements of net   7
# Generating CLEAN scenario No.   8...
# Running Power Flow Analysis for net   8
# Updating measurements of net   8
# Generating CLEAN scenario No.   9...
# Running Power Flow Analysis for net   9
# Updating measurements of net   9
# Generating CLEAN scenario No.  10...
# Running Power Flow Analysis for net  10
# Updating measurements of net  10
# Generating CLEAN scenario No.  11...
# Running Power Flow Analysis for net  11
# Updating measurements of net  11
# Generating CLEAN scenario No.  12...
# Running Power Flow Analysis for net  12
# Updating measurements of net  12
# Generating CLEAN scenario No.  13...
# Running Power Flow Analysis for net  13
# Updating measurements of net  13
# Generating CLEAN scenario No.  14...
# Running Power Flow Analysis for net  14
# Updating measurements of net  14
# Generating CLEAN scenario No.  15...
# Running Power Flow Analysis for net  15
# Updating measurements of net  15
# Generating CLEAN scenario No.  16...
# Running Power Flow Analysis for net  16
# Updating measurements of net  16
# Generating CLEAN scenario No.  17...
# Running Power Flow Analysis for net  17
# Updating measurements of net  17
# Generating CLEAN scenario No.  18...
# Running Power Flow Analysis for net  18
# Updating measurements of net  18
# Generating CLEAN scenario No.  19...
# Running Power Flow Analysis for net  19
# Updating measurements of net  19
# Generating CLEAN scenario No.  20...
# Running Power Flow Analysis for net  20
# Updating measurements of net  20
# Generating CLEAN scenario No.  21...
# Running Power Flow Analysis for net  21
# Updating measurements of net  21
# Generating CLEAN scenario No.  22...
# Running Power Flow Analysis for net  22
# Updating measurements of net  22
# Generating CLEAN scenario No.  23...
# Running Power Flow Analysis for net  23
# Updating measurements of net  23
# Generating CLEAN scenario No.  24...
# Running Power Flow Analysis for net  24
# Updating measurements of net  24
# Generating CLEAN scenario No.  25...
# Running Power Flow Analysis for net  25
# Updating measurements of net  25
# Generating CLEAN scenario No.  26...
# Running Power Flow Analysis for net  26
# Updating measurements of net  26
# Generating CLEAN scenario No.  27...
# Running Power Flow Analysis for net  27
# Updating measurements of net  27
# Generating CLEAN scenario No.  28...
# Running Power Flow Analysis for net  28
# Updating measurements of net  28
# Generating CLEAN scenario No.  29...
# Running Power Flow Analysis for net  29
# Updating measurements of net  29
# Generating CLEAN scenario No.  30...
# Running Power Flow Analysis for net  30
# Updating measurements of net  30
# Generating CLEAN scenario No.  31...
# Running Power Flow Analysis for net  31
# Updating measurements of net  31
# Generating CLEAN scenario No.  32...
# Running Power Flow Analysis for net  32
# Updating measurements of net  32
# Generating CLEAN scenario No.  33...
# Running Power Flow Analysis for net  33
# Updating measurements of net  33
# Generating CLEAN scenario No.  34...
# Running Power Flow Analysis for net  34
# Updating measurements of net  34
# Generating CLEAN scenario No.  35...
# Running Power Flow Analysis for net  35
# Updating measurements of net  35
# Generating CLEAN scenario No.  36...
# Running Power Flow Analysis for net  36
# Updating measurements of net  36
# Generating CLEAN scenario No.  37...
# Running Power Flow Analysis for net  37
# Updating measurements of net  37
# Generating CLEAN scenario No.  38...
# Running Power Flow Analysis for net  38
# Updating measurements of net  38
# Generating CLEAN scenario No.  39...
# Running Power Flow Analysis for net  39
# Updating measurements of net  39
# Generating CLEAN scenario No.  40...
# Running Power Flow Analysis for net  40
# Updating measurements of net  40
# Generating CLEAN scenario No.  41...
# Running Power Flow Analysis for net  41
# Updating measurements of net  41
# Generating CLEAN scenario No.  42...
# Running Power Flow Analysis for net  42
# Updating measurements of net  42
# Generating CLEAN scenario No.  43...
# Running Power Flow Analysis for net  43
# Updating measurements of net  43
# Generating CLEAN scenario No.  44...
# Running Power Flow Analysis for net  44
# Updating measurements of net  44
# Generating CLEAN scenario No.  45...
# Running Power Flow Analysis for net  45
# Updating measurements of net  45
# Generating CLEAN scenario No.  46...
# Running Power Flow Analysis for net  46
# Updating measurements of net  46
# Generating CLEAN scenario No.  47...
# Running Power Flow Analysis for net  47
# Updating measurements of net  47
# Generating CLEAN scenario No.  48...
# Running Power Flow Analysis for net  48
# Updating measurements of net  48
# Generating CLEAN scenario No.  49...
# Running Power Flow Analysis for net  49
# Updating measurements of net  49
# Generating CLEAN scenario No.  50...
# Running Power Flow Analysis for net  50
# Updating measurements of net  50
# Generating CLEAN scenario No.  51...
# Running Power Flow Analysis for net  51
# Updating measurements of net  51
# Generating CLEAN scenario No.  52...
# Running Power Flow Analysis for net  52
# Updating measurements of net  52
# Generating CLEAN scenario No.  53...
# Running Power Flow Analysis for net  53
# Updating measurements of net  53
# Generating CLEAN scenario No.  54...
# Running Power Flow Analysis for net  54
# Updating measurements of net  54
# Generating CLEAN scenario No.  55...
# Running Power Flow Analysis for net  55
# Updating measurements of net  55
# Generating CLEAN scenario No.  56...
# Running Power Flow Analysis for net  56
# Updating measurements of net  56
# Generating CLEAN scenario No.  57...
# Running Power Flow Analysis for net  57
# Updating measurements of net  57
# Generating CLEAN scenario No.  58...
# Running Power Flow Analysis for net  58
# Updating measurements of net  58
# Generating CLEAN scenario No.  59...
# Running Power Flow Analysis for net  59
# Updating measurements of net  59
# Generating CLEAN scenario No.  60...
# Running Power Flow Analysis for net  60
# Updating measurements of net  60
# Generating CLEAN scenario No.  61...
# Running Power Flow Analysis for net  61
# Updating measurements of net  61
# Generating CLEAN scenario No.  62...
# Running Power Flow Analysis for net  62
# Updating measurements of net  62
# Generating CLEAN scenario No.  63...
# Running Power Flow Analysis for net  63
# Updating measurements of net  63
# Generating CLEAN scenario No.  64...
# Running Power Flow Analysis for net  64
# Updating measurements of net  64
# Generating CLEAN scenario No.  65...
# Running Power Flow Analysis for net  65
# Updating measurements of net  65
# Generating CLEAN scenario No.  66...
# Running Power Flow Analysis for net  66
# Updating measurements of net  66
# Generating CLEAN scenario No.  67...
# Running Power Flow Analysis for net  67
# Updating measurements of net  67
# Generating CLEAN scenario No.  68...
# Running Power Flow Analysis for net  68
# Updating measurements of net  68
# Generating CLEAN scenario No.  69...
# Running Power Flow Analysis for net  69
# Updating measurements of net  69
# Generating CLEAN scenario No.  70...
# Running Power Flow Analysis for net  70
# Updating measurements of net  70
# Generating CLEAN scenario No.  71...
# Running Power Flow Analysis for net  71
# Updating measurements of net  71
# Generating CLEAN scenario No.  72...
# Running Power Flow Analysis for net  72
# Updating measurements of net  72
# Generating CLEAN scenario No.  73...
# Running Power Flow Analysis for net  73
# Updating measurements of net  73
# Generating CLEAN scenario No.  74...
# Running Power Flow Analysis for net  74
# Updating measurements of net  74
# Generating CLEAN scenario No.  75...
# Running Power Flow Analysis for net  75
# Updating measurements of net  75
# Generating CLEAN scenario No.  76...
# Running Power Flow Analysis for net  76
# Updating measurements of net  76
# Generating CLEAN scenario No.  77...
# Running Power Flow Analysis for net  77
# Updating measurements of net  77
# Generating CLEAN scenario No.  78...
# Running Power Flow Analysis for net  78
# Updating measurements of net  78
# Generating CLEAN scenario No.  79...
# Running Power Flow Analysis for net  79
# Updating measurements of net  79
# Generating CLEAN scenario No.  80...
# Running Power Flow Analysis for net  80
# Updating measurements of net  80
# Generating CLEAN scenario No.  81...
# Running Power Flow Analysis for net  81
# Updating measurements of net  81
# Generating CLEAN scenario No.  82...
# Running Power Flow Analysis for net  82
# Updating measurements of net  82
# Generating CLEAN scenario No.  83...
# Running Power Flow Analysis for net  83
# Updating measurements of net  83
# Generating CLEAN scenario No.  84...
# Running Power Flow Analysis for net  84
# Updating measurements of net  84
# Generating CLEAN scenario No.  85...
# Running Power Flow Analysis for net  85
# Updating measurements of net  85
# Generating CLEAN scenario No.  86...
# Running Power Flow Analysis for net  86
# Updating measurements of net  86
# Generating CLEAN scenario No.  87...
# Running Power Flow Analysis for net  87
# Updating measurements of net  87
# Generating CLEAN scenario No.  88...
# Running Power Flow Analysis for net  88
# Updating measurements of net  88
# Generating CLEAN scenario No.  89...
# Running Power Flow Analysis for net  89
# Updating measurements of net  89
# Generating CLEAN scenario No.  90...
# Running Power Flow Analysis for net  90
# Updating measurements of net  90
# Generating CLEAN scenario No.  91...
# Running Power Flow Analysis for net  91
# Updating measurements of net  91
# Generating CLEAN scenario No.  92...
# Running Power Flow Analysis for net  92
# Updating measurements of net  92
# Generating CLEAN scenario No.  93...
# Running Power Flow Analysis for net  93
# Updating measurements of net  93
# Generating CLEAN scenario No.  94...
# Running Power Flow Analysis for net  94
# Updating measurements of net  94
# Generating CLEAN scenario No.  95...
# Running Power Flow Analysis for net  95
# Updating measurements of net  95
# Generating CLEAN scenario No.  96...
# Running Power Flow Analysis for net  96
# Updating measurements of net  96
# Generating CLEAN scenario No.  97...
# Running Power Flow Analysis for net  97
# Updating measurements of net  97
# Generating CLEAN scenario No.  98...
# Running Power Flow Analysis for net  98
# Updating measurements of net  98
# Generating CLEAN scenario No.  99...
# Running Power Flow Analysis for net  99
# Updating measurements of net  99
# Generating CLEAN scenario No. 100...
# Running Power Flow Analysis for net 100
# Updating measurements of net 100
# Generating CLEAN scenario No. 101...
# Running Power Flow Analysis for net 101
# Updating measurements of net 101
# Generating CLEAN scenario No. 102...
# Running Power Flow Analysis for net 102
# Updating measurements of net 102
# Generating CLEAN scenario No. 103...
# Running Power Flow Analysis for net 103
# Updating measurements of net 103
# Generating CLEAN scenario No. 104...
# Running Power Flow Analysis for net 104
# Updating measurements of net 104
# Generating CLEAN scenario No. 105...
# Running Power Flow Analysis for net 105
# Updating measurements of net 105
# Generating CLEAN scenario No. 106...
# Running Power Flow Analysis for net 106
# Updating measurements of net 106
# Generating CLEAN scenario No. 107...
# Running Power Flow Analysis for net 107
# Updating measurements of net 107
# Generating CLEAN scenario No. 108...
# Running Power Flow Analysis for net 108
# Updating measurements of net 108
# Generating CLEAN scenario No. 109...
# Running Power Flow Analysis for net 109
# Updating measurements of net 109
# Generating CLEAN scenario No. 110...
# Running Power Flow Analysis for net 110
# Updating measurements of net 110
# Generating CLEAN scenario No. 111...
# Running Power Flow Analysis for net 111
# Updating measurements of net 111
# Generating CLEAN scenario No. 112...
# Running Power Flow Analysis for net 112
# Updating measurements of net 112
# Generating CLEAN scenario No. 113...
# Running Power Flow Analysis for net 113
# Updating measurements of net 113
# Generating CLEAN scenario No. 114...
# Running Power Flow Analysis for net 114
# Updating measurements of net 114
# Generating CLEAN scenario No. 115...
# Running Power Flow Analysis for net 115
# Updating measurements of net 115
# Generating CLEAN scenario No. 116...
# Running Power Flow Analysis for net 116
# Updating measurements of net 116
# Generating CLEAN scenario No. 117...
# Running Power Flow Analysis for net 117
# Updating measurements of net 117
# Generating CLEAN scenario No. 118...
# Running Power Flow Analysis for net 118
# Updating measurements of net 118
# Generating CLEAN scenario No. 119...
# Running Power Flow Analysis for net 119
# Updating measurements of net 119
# Generating CLEAN scenario No. 120...
# Running Power Flow Analysis for net 120
# Updating measurements of net 120
# Generating CLEAN scenario No. 121...
# Running Power Flow Analysis for net 121
# Updating measurements of net 121
# Generating CLEAN scenario No. 122...
# Running Power Flow Analysis for net 122
# Updating measurements of net 122
# Generating CLEAN scenario No. 123...
# Running Power Flow Analysis for net 123
# Updating measurements of net 123
# Generating CLEAN scenario No. 124...
# Running Power Flow Analysis for net 124
# Updating measurements of net 124
# Generating CLEAN scenario No. 125...
# Running Power Flow Analysis for net 125
# Updating measurements of net 125
# Generating CLEAN scenario No. 126...
# Running Power Flow Analysis for net 126
# Updating measurements of net 126
# Generating CLEAN scenario No. 127...
# Running Power Flow Analysis for net 127
# Updating measurements of net 127
# Generating CLEAN scenario No. 128...
# Running Power Flow Analysis for net 128
# Updating measurements of net 128
# Generating CLEAN scenario No. 129...
# Running Power Flow Analysis for net 129
# Updating measurements of net 129
# Generating CLEAN scenario No. 130...
# Running Power Flow Analysis for net 130
# Updating measurements of net 130
# Generating CLEAN scenario No. 131...
# Running Power Flow Analysis for net 131
# Updating measurements of net 131
# Generating CLEAN scenario No. 132...
# Running Power Flow Analysis for net 132
# Updating measurements of net 132
# Generating CLEAN scenario No. 133...
# Running Power Flow Analysis for net 133
# Updating measurements of net 133
# Generating CLEAN scenario No. 134...
# Running Power Flow Analysis for net 134
# Updating measurements of net 134
# Generating CLEAN scenario No. 135...
# Running Power Flow Analysis for net 135
# Updating measurements of net 135
# Generating CLEAN scenario No. 136...
# Running Power Flow Analysis for net 136
# Updating measurements of net 136
# Generating CLEAN scenario No. 137...
# Running Power Flow Analysis for net 137
# Updating measurements of net 137
# Generating CLEAN scenario No. 138...
# Running Power Flow Analysis for net 138
# Updating measurements of net 138
# Generating CLEAN scenario No. 139...
# Running Power Flow Analysis for net 139
# Updating measurements of net 139
# Generating CLEAN scenario No. 140...
# Running Power Flow Analysis for net 140
# Updating measurements of net 140
# Generating CLEAN scenario No. 141...
# Running Power Flow Analysis for net 141
# Updating measurements of net 141
# Generating CLEAN scenario No. 142...
# Running Power Flow Analysis for net 142
# Updating measurements of net 142
# Generating CLEAN scenario No. 143...
# Running Power Flow Analysis for net 143
# Updating measurements of net 143
# Generating CLEAN scenario No. 144...
# Running Power Flow Analysis for net 144
# Updating measurements of net 144
# Generating CLEAN scenario No. 145...
# Running Power Flow Analysis for net 145
# Updating measurements of net 145
# Generating CLEAN scenario No. 146...
# Running Power Flow Analysis for net 146
# Updating measurements of net 146
# Generating CLEAN scenario No. 147...
# Running Power Flow Analysis for net 147
# Updating measurements of net 147
# Generating CLEAN scenario No. 148...
# Running Power Flow Analysis for net 148
# Updating measurements of net 148
# Generating CLEAN scenario No. 149...
# Running Power Flow Analysis for net 149
# Updating measurements of net 149
# Generating CLEAN scenario No. 150...
# Running Power Flow Analysis for net 150
# Updating measurements of net 150
# Generating CLEAN scenario No. 151...
# Running Power Flow Analysis for net 151
# Updating measurements of net 151
# Generating CLEAN scenario No. 152...
# Running Power Flow Analysis for net 152
# Updating measurements of net 152
# Generating CLEAN scenario No. 153...
# Running Power Flow Analysis for net 153
# Updating measurements of net 153
# Generating CLEAN scenario No. 154...
# Running Power Flow Analysis for net 154
# Updating measurements of net 154
# Generating CLEAN scenario No. 155...
# Running Power Flow Analysis for net 155
# Updating measurements of net 155
# Generating CLEAN scenario No. 156...
# Running Power Flow Analysis for net 156
# Updating measurements of net 156
# Generating CLEAN scenario No. 157...
# Running Power Flow Analysis for net 157
# Updating measurements of net 157
# Generating CLEAN scenario No. 158...
# Running Power Flow Analysis for net 158
# Updating measurements of net 158
# Generating CLEAN scenario No. 159...
# Running Power Flow Analysis for net 159
# Updating measurements of net 159
# Generating CLEAN scenario No. 160...
# Running Power Flow Analysis for net 160
# Updating measurements of net 160
# Generating CLEAN scenario No. 161...
# Running Power Flow Analysis for net 161
# Updating measurements of net 161
# Generating CLEAN scenario No. 162...
# Running Power Flow Analysis for net 162
# Updating measurements of net 162
# Generating CLEAN scenario No. 163...
# Running Power Flow Analysis for net 163
# Updating measurements of net 163
# Generating CLEAN scenario No. 164...
# Running Power Flow Analysis for net 164
# Updating measurements of net 164
# Generating CLEAN scenario No. 165...
# Running Power Flow Analysis for net 165
# Updating measurements of net 165
# Generating CLEAN scenario No. 166...
# Running Power Flow Analysis for net 166
# Updating measurements of net 166
# Generating CLEAN scenario No. 167...
# Running Power Flow Analysis for net 167
# Updating measurements of net 167
# Generating CLEAN scenario No. 168...
# Running Power Flow Analysis for net 168
# Updating measurements of net 168
# Generating CLEAN scenario No. 169...
# Running Power Flow Analysis for net 169
# Updating measurements of net 169
# Generating CLEAN scenario No. 170...
# Running Power Flow Analysis for net 170
# Updating measurements of net 170
# Generating CLEAN scenario No. 171...
# Running Power Flow Analysis for net 171
# Updating measurements of net 171
# Generating CLEAN scenario No. 172...
# Running Power Flow Analysis for net 172
# Updating measurements of net 172
# Generating CLEAN scenario No. 173...
# Running Power Flow Analysis for net 173
# Updating measurements of net 173
# Generating CLEAN scenario No. 174...
# Running Power Flow Analysis for net 174
# Updating measurements of net 174
# Generating CLEAN scenario No. 175...
# Running Power Flow Analysis for net 175
# Updating measurements of net 175
# Generating CLEAN scenario No. 176...
# Running Power Flow Analysis for net 176
# Updating measurements of net 176
# Generating CLEAN scenario No. 177...
# Running Power Flow Analysis for net 177
# Updating measurements of net 177
# Generating CLEAN scenario No. 178...
# Running Power Flow Analysis for net 178
# Updating measurements of net 178
# Generating CLEAN scenario No. 179...
# Running Power Flow Analysis for net 179
# Updating measurements of net 179
# Generating CLEAN scenario No. 180...
# Running Power Flow Analysis for net 180
# Updating measurements of net 180
# Generating CLEAN scenario No. 181...
# Running Power Flow Analysis for net 181
# Updating measurements of net 181
# Generating CLEAN scenario No. 182...
# Running Power Flow Analysis for net 182
# Updating measurements of net 182
# Generating CLEAN scenario No. 183...
# Running Power Flow Analysis for net 183
# Updating measurements of net 183
# Generating CLEAN scenario No. 184...
# Running Power Flow Analysis for net 184
# Updating measurements of net 184
# Generating CLEAN scenario No. 185...
# Running Power Flow Analysis for net 185
# Updating measurements of net 185
# Generating CLEAN scenario No. 186...
# Running Power Flow Analysis for net 186
# Updating measurements of net 186
# Generating CLEAN scenario No. 187...
# Running Power Flow Analysis for net 187
# Updating measurements of net 187
# Generating CLEAN scenario No. 188...
# Running Power Flow Analysis for net 188
# Updating measurements of net 188
# Generating CLEAN scenario No. 189...
# Running Power Flow Analysis for net 189
# Updating measurements of net 189
# Generating CLEAN scenario No. 190...
# Running Power Flow Analysis for net 190
# Updating measurements of net 190
# Generating CLEAN scenario No. 191...
# Running Power Flow Analysis for net 191
# Updating measurements of net 191
# Generating CLEAN scenario No. 192...
# Running Power Flow Analysis for net 192
# Updating measurements of net 192
# Generating CLEAN scenario No. 193...
# Running Power Flow Analysis for net 193
# Updating measurements of net 193
# Generating CLEAN scenario No. 194...
# Running Power Flow Analysis for net 194
# Updating measurements of net 194
# Generating CLEAN scenario No. 195...
# Running Power Flow Analysis for net 195
# Updating measurements of net 195
# Generating CLEAN scenario No. 196...
# Running Power Flow Analysis for net 196
# Updating measurements of net 196
# Generating CLEAN scenario No. 197...
# Running Power Flow Analysis for net 197
# Updating measurements of net 197
# Generating CLEAN scenario No. 198...
# Running Power Flow Analysis for net 198
# Updating measurements of net 198
# Generating CLEAN scenario No. 199...
# Running Power Flow Analysis for net 199
# Updating measurements of net 199
# Generating CLEAN scenario No. 200...
# Running Power Flow Analysis for net 200
# Updating measurements of net 200
# Generating CLEAN scenario No. 201...
# Running Power Flow Analysis for net 201
# Updating measurements of net 201
# Generating CLEAN scenario No. 202...
# Running Power Flow Analysis for net 202
# Updating measurements of net 202
# Generating CLEAN scenario No. 203...
# Running Power Flow Analysis for net 203
# Updating measurements of net 203
# Generating CLEAN scenario No. 204...
# Running Power Flow Analysis for net 204
# Updating measurements of net 204
# Generating CLEAN scenario No. 205...
# Running Power Flow Analysis for net 205
# Updating measurements of net 205
# Generating CLEAN scenario No. 206...
# Running Power Flow Analysis for net 206
# Updating measurements of net 206
# Generating CLEAN scenario No. 207...
# Running Power Flow Analysis for net 207
# Updating measurements of net 207
# Generating CLEAN scenario No. 208...
# Running Power Flow Analysis for net 208
# Updating measurements of net 208
# Generating CLEAN scenario No. 209...
# Running Power Flow Analysis for net 209
# Updating measurements of net 209
# Generating CLEAN scenario No. 210...
# Running Power Flow Analysis for net 210
# Updating measurements of net 210
# Generating CLEAN scenario No. 211...
# Running Power Flow Analysis for net 211
# Updating measurements of net 211
# Generating CLEAN scenario No. 212...
# Running Power Flow Analysis for net 212
# Updating measurements of net 212
# Generating CLEAN scenario No. 213...
# Running Power Flow Analysis for net 213
# Updating measurements of net 213
# Generating CLEAN scenario No. 214...
# Running Power Flow Analysis for net 214
# Updating measurements of net 214
# Generating CLEAN scenario No. 215...
# Running Power Flow Analysis for net 215
# Updating measurements of net 215
# Generating CLEAN scenario No. 216...
# Running Power Flow Analysis for net 216
# Updating measurements of net 216
# Generating CLEAN scenario No. 217...
# Running Power Flow Analysis for net 217
# Updating measurements of net 217
# Generating CLEAN scenario No. 218...
# Running Power Flow Analysis for net 218
# Updating measurements of net 218
# Generating CLEAN scenario No. 219...
# Running Power Flow Analysis for net 219
# Updating measurements of net 219
# Generating CLEAN scenario No. 220...
# Running Power Flow Analysis for net 220
# Updating measurements of net 220
# Generating CLEAN scenario No. 221...
# Running Power Flow Analysis for net 221
# Updating measurements of net 221
# Generating CLEAN scenario No. 222...
# Running Power Flow Analysis for net 222
# Updating measurements of net 222
# Generating CLEAN scenario No. 223...
# Running Power Flow Analysis for net 223
# Updating measurements of net 223
# Generating CLEAN scenario No. 224...
# Running Power Flow Analysis for net 224
# Updating measurements of net 224
# Generating CLEAN scenario No. 225...
# Running Power Flow Analysis for net 225
# Updating measurements of net 225
# Generating CLEAN scenario No. 226...
# Running Power Flow Analysis for net 226
# Updating measurements of net 226
# Generating CLEAN scenario No. 227...
# Running Power Flow Analysis for net 227
# Updating measurements of net 227
# Generating CLEAN scenario No. 228...
# Running Power Flow Analysis for net 228
# Updating measurements of net 228
# Generating CLEAN scenario No. 229...
# Running Power Flow Analysis for net 229
# Updating measurements of net 229
# Generating CLEAN scenario No. 230...
# Running Power Flow Analysis for net 230
# Updating measurements of net 230
# Generating CLEAN scenario No. 231...
# Running Power Flow Analysis for net 231
# Updating measurements of net 231
# Generating CLEAN scenario No. 232...
# Running Power Flow Analysis for net 232
# Updating measurements of net 232
# Generating CLEAN scenario No. 233...
# Running Power Flow Analysis for net 233
# Updating measurements of net 233
# Generating CLEAN scenario No. 234...
# Running Power Flow Analysis for net 234
# Updating measurements of net 234
# Generating CLEAN scenario No. 235...
# Running Power Flow Analysis for net 235
# Updating measurements of net 235
# Generating CLEAN scenario No. 236...
# Running Power Flow Analysis for net 236
# Updating measurements of net 236
# Generating CLEAN scenario No. 237...
# Running Power Flow Analysis for net 237
# Updating measurements of net 237
# Generating CLEAN scenario No. 238...
# Running Power Flow Analysis for net 238
# Updating measurements of net 238
# Generating CLEAN scenario No. 239...
# Running Power Flow Analysis for net 239
# Updating measurements of net 239
# Generating CLEAN scenario No. 240...
# Running Power Flow Analysis for net 240
# Updating measurements of net 240
# Generating CLEAN scenario No. 241...
# Running Power Flow Analysis for net 241
# Updating measurements of net 241
# Generating CLEAN scenario No. 242...
# Running Power Flow Analysis for net 242
# Updating measurements of net 242
# Generating CLEAN scenario No. 243...
# Running Power Flow Analysis for net 243
# Updating measurements of net 243
# Generating CLEAN scenario No. 244...
# Running Power Flow Analysis for net 244
# Updating measurements of net 244
# Generating CLEAN scenario No. 245...
# Running Power Flow Analysis for net 245
# Updating measurements of net 245
# Generating CLEAN scenario No. 246...
# Running Power Flow Analysis for net 246
# Updating measurements of net 246
# Generating CLEAN scenario No. 247...
# Running Power Flow Analysis for net 247
# Updating measurements of net 247
# Generating CLEAN scenario No. 248...
# Running Power Flow Analysis for net 248
# Updating measurements of net 248
# Generating CLEAN scenario No. 249...
# Running Power Flow Analysis for net 249
# Updating measurements of net 249
# Generating CLEAN scenario No. 250...
# Running Power Flow Analysis for net 250
# Updating measurements of net 250
# Generating CLEAN scenario No. 251...
# Running Power Flow Analysis for net 251
# Updating measurements of net 251
# Generating CLEAN scenario No. 252...
# Running Power Flow Analysis for net 252
# Updating measurements of net 252
# Generating CLEAN scenario No. 253...
# Running Power Flow Analysis for net 253
# Updating measurements of net 253
# Generating CLEAN scenario No. 254...
# Running Power Flow Analysis for net 254
# Updating measurements of net 254
# Generating CLEAN scenario No. 255...
# Running Power Flow Analysis for net 255
# Updating measurements of net 255
# Generating CLEAN scenario No. 256...
# Running Power Flow Analysis for net 256
# Updating measurements of net 256
# Generating CLEAN scenario No. 257...
# Running Power Flow Analysis for net 257
# Updating measurements of net 257
# Generating CLEAN scenario No. 258...
# Running Power Flow Analysis for net 258
# Updating measurements of net 258
# Generating CLEAN scenario No. 259...
# Running Power Flow Analysis for net 259
# Updating measurements of net 259
# Generating CLEAN scenario No. 260...
# Running Power Flow Analysis for net 260
# Updating measurements of net 260
# Generating CLEAN scenario No. 261...
# Running Power Flow Analysis for net 261
# Updating measurements of net 261
# Generating CLEAN scenario No. 262...
# Running Power Flow Analysis for net 262
# Updating measurements of net 262
# Generating CLEAN scenario No. 263...
# Running Power Flow Analysis for net 263
# Updating measurements of net 263
# Generating CLEAN scenario No. 264...
# Running Power Flow Analysis for net 264
# Updating measurements of net 264
# Generating CLEAN scenario No. 265...
# Running Power Flow Analysis for net 265
# Updating measurements of net 265
# Generating CLEAN scenario No. 266...
# Running Power Flow Analysis for net 266
# Updating measurements of net 266
# Generating CLEAN scenario No. 267...
# Running Power Flow Analysis for net 267
# Updating measurements of net 267
# Generating CLEAN scenario No. 268...
# Running Power Flow Analysis for net 268
# Updating measurements of net 268
# Generating CLEAN scenario No. 269...
# Running Power Flow Analysis for net 269
# Updating measurements of net 269
# Generating CLEAN scenario No. 270...
# Running Power Flow Analysis for net 270
# Updating measurements of net 270
# Generating CLEAN scenario No. 271...
# Running Power Flow Analysis for net 271
# Updating measurements of net 271
# Generating CLEAN scenario No. 272...
# Running Power Flow Analysis for net 272
# Updating measurements of net 272
# Generating CLEAN scenario No. 273...
# Running Power Flow Analysis for net 273
# Updating measurements of net 273
# Generating CLEAN scenario No. 274...
# Running Power Flow Analysis for net 274
# Updating measurements of net 274
# Generating CLEAN scenario No. 275...
# Running Power Flow Analysis for net 275
# Updating measurements of net 275
# Generating CLEAN scenario No. 276...
# Running Power Flow Analysis for net 276
# Updating measurements of net 276
# Generating CLEAN scenario No. 277...
# Running Power Flow Analysis for net 277
# Updating measurements of net 277
# Generating CLEAN scenario No. 278...
# Running Power Flow Analysis for net 278
# Updating measurements of net 278
# Generating CLEAN scenario No. 279...
# Running Power Flow Analysis for net 279
# Updating measurements of net 279
# Generating CLEAN scenario No. 280...
# Running Power Flow Analysis for net 280
# Updating measurements of net 280
# Generating CLEAN scenario No. 281...
# Running Power Flow Analysis for net 281
# Updating measurements of net 281
# Generating CLEAN scenario No. 282...
# Running Power Flow Analysis for net 282
# Updating measurements of net 282
# Generating CLEAN scenario No. 283...
# Running Power Flow Analysis for net 283
# Updating measurements of net 283
# Generating CLEAN scenario No. 284...
# Running Power Flow Analysis for net 284
# Updating measurements of net 284
# Generating CLEAN scenario No. 285...
# Running Power Flow Analysis for net 285
# Updating measurements of net 285
# Generating CLEAN scenario No. 286...
# Running Power Flow Analysis for net 286
# Updating measurements of net 286
# Generating CLEAN scenario No. 287...
# Running Power Flow Analysis for net 287
# Updating measurements of net 287
# Generating CLEAN scenario No. 288...
# Running Power Flow Analysis for net 288
# Updating measurements of net 288
# Generating CLEAN scenario No. 289...
# Running Power Flow Analysis for net 289
# Updating measurements of net 289
# Generating CLEAN scenario No. 290...
# Running Power Flow Analysis for net 290
# Updating measurements of net 290
# Generating CLEAN scenario No. 291...
# Running Power Flow Analysis for net 291
# Updating measurements of net 291
# Generating CLEAN scenario No. 292...
# Running Power Flow Analysis for net 292
# Updating measurements of net 292
# Generating CLEAN scenario No. 293...
# Running Power Flow Analysis for net 293
# Updating measurements of net 293
# Generating CLEAN scenario No. 294...
# Running Power Flow Analysis for net 294
# Updating measurements of net 294
# Generating CLEAN scenario No. 295...
# Running Power Flow Analysis for net 295
# Updating measurements of net 295
# Generating CLEAN scenario No. 296...
# Running Power Flow Analysis for net 296
# Updating measurements of net 296
# Generating CLEAN scenario No. 297...
# Running Power Flow Analysis for net 297
# Updating measurements of net 297
# Generating CLEAN scenario No. 298...
# Running Power Flow Analysis for net 298
# Updating measurements of net 298
# Generating CLEAN scenario No. 299...
# Running Power Flow Analysis for net 299
# Updating measurements of net 299
# Generating CLEAN scenario No. 300...
# Running Power Flow Analysis for net 300
# Updating measurements of net 300
# Generating CLEAN scenario No. 301...
# Running Power Flow Analysis for net 301
# Updating measurements of net 301
# Generating CLEAN scenario No. 302...
# Running Power Flow Analysis for net 302
# Updating measurements of net 302
# Generating CLEAN scenario No. 303...
# Running Power Flow Analysis for net 303
# Updating measurements of net 303
# Generating CLEAN scenario No. 304...
# Running Power Flow Analysis for net 304
# Updating measurements of net 304
# Generating CLEAN scenario No. 305...
# Running Power Flow Analysis for net 305
# Updating measurements of net 305
# Generating CLEAN scenario No. 306...
# Running Power Flow Analysis for net 306
# Updating measurements of net 306
# Generating CLEAN scenario No. 307...
# Running Power Flow Analysis for net 307
# Updating measurements of net 307
# Generating CLEAN scenario No. 308...
# Running Power Flow Analysis for net 308
# Updating measurements of net 308
# Generating CLEAN scenario No. 309...
# Running Power Flow Analysis for net 309
# Updating measurements of net 309
# Generating CLEAN scenario No. 310...
# Running Power Flow Analysis for net 310
# Updating measurements of net 310
# Generating CLEAN scenario No. 311...
# Running Power Flow Analysis for net 311
# Updating measurements of net 311
# Generating CLEAN scenario No. 312...
# Running Power Flow Analysis for net 312
# Updating measurements of net 312
# Generating CLEAN scenario No. 313...
# Running Power Flow Analysis for net 313
# Updating measurements of net 313
# Generating CLEAN scenario No. 314...
# Running Power Flow Analysis for net 314
# Updating measurements of net 314
# Generating CLEAN scenario No. 315...
# Running Power Flow Analysis for net 315
# Updating measurements of net 315
# Generating CLEAN scenario No. 316...
# Running Power Flow Analysis for net 316
# Updating measurements of net 316
# Generating CLEAN scenario No. 317...
# Running Power Flow Analysis for net 317
# Updating measurements of net 317
# Generating CLEAN scenario No. 318...
# Running Power Flow Analysis for net 318
# Updating measurements of net 318
# Generating CLEAN scenario No. 319...
# Running Power Flow Analysis for net 319
# Updating measurements of net 319
# Generating CLEAN scenario No. 320...
# Running Power Flow Analysis for net 320
# Updating measurements of net 320
# Generating CLEAN scenario No. 321...
# Running Power Flow Analysis for net 321
# Updating measurements of net 321
# Generating CLEAN scenario No. 322...
# Running Power Flow Analysis for net 322
# Updating measurements of net 322
# Generating CLEAN scenario No. 323...
# Running Power Flow Analysis for net 323
# Updating measurements of net 323
# Generating CLEAN scenario No. 324...
# Running Power Flow Analysis for net 324
# Updating measurements of net 324
# Generating CLEAN scenario No. 325...
# Running Power Flow Analysis for net 325
# Updating measurements of net 325
# Generating CLEAN scenario No. 326...
# Running Power Flow Analysis for net 326
# Updating measurements of net 326
# Generating CLEAN scenario No. 327...
# Running Power Flow Analysis for net 327
# Updating measurements of net 327
# Generating CLEAN scenario No. 328...
# Running Power Flow Analysis for net 328
# Updating measurements of net 328
# Generating CLEAN scenario No. 329...
# Running Power Flow Analysis for net 329
# Updating measurements of net 329
# Generating CLEAN scenario No. 330...
# Running Power Flow Analysis for net 330
# Updating measurements of net 330
# Generating CLEAN scenario No. 331...
# Running Power Flow Analysis for net 331
# Updating measurements of net 331
# Generating CLEAN scenario No. 332...
# Running Power Flow Analysis for net 332
# Updating measurements of net 332
# Generating CLEAN scenario No. 333...
# Running Power Flow Analysis for net 333
# Updating measurements of net 333
# Generating CLEAN scenario No. 334...
# Running Power Flow Analysis for net 334
# Updating measurements of net 334
# Generating CLEAN scenario No. 335...
# Running Power Flow Analysis for net 335
# Updating measurements of net 335
# Generating CLEAN scenario No. 336...
# Running Power Flow Analysis for net 336
# Updating measurements of net 336
# Generating CLEAN scenario No. 337...
# Running Power Flow Analysis for net 337
# Updating measurements of net 337
# Generating CLEAN scenario No. 338...
# Running Power Flow Analysis for net 338
# Updating measurements of net 338
# Generating CLEAN scenario No. 339...
# Running Power Flow Analysis for net 339
# Updating measurements of net 339
# Generating CLEAN scenario No. 340...
# Running Power Flow Analysis for net 340
# Updating measurements of net 340
# Generating CLEAN scenario No. 341...
# Running Power Flow Analysis for net 341
# Updating measurements of net 341
# Generating CLEAN scenario No. 342...
# Running Power Flow Analysis for net 342
# Updating measurements of net 342
# Generating CLEAN scenario No. 343...
# Running Power Flow Analysis for net 343
# Updating measurements of net 343
# Generating CLEAN scenario No. 344...
# Running Power Flow Analysis for net 344
# Updating measurements of net 344
# Generating CLEAN scenario No. 345...
# Running Power Flow Analysis for net 345
# Updating measurements of net 345
# Generating CLEAN scenario No. 346...
# Running Power Flow Analysis for net 346
# Updating measurements of net 346
# Generating CLEAN scenario No. 347...
# Running Power Flow Analysis for net 347
# Updating measurements of net 347
# Generating CLEAN scenario No. 348...
# Running Power Flow Analysis for net 348
# Updating measurements of net 348
# Generating CLEAN scenario No. 349...
# Running Power Flow Analysis for net 349
# Updating measurements of net 349
# Generating CLEAN scenario No. 350...
# Running Power Flow Analysis for net 350
# Updating measurements of net 350
# Generating CLEAN scenario No. 351...
# Running Power Flow Analysis for net 351
# Updating measurements of net 351
# Generating CLEAN scenario No. 352...
# Running Power Flow Analysis for net 352
# Updating measurements of net 352
# Generating CLEAN scenario No. 353...
# Running Power Flow Analysis for net 353
# Updating measurements of net 353
# Generating CLEAN scenario No. 354...
# Running Power Flow Analysis for net 354
# Updating measurements of net 354
# Generating CLEAN scenario No. 355...
# Running Power Flow Analysis for net 355
# Updating measurements of net 355
# Generating CLEAN scenario No. 356...
# Running Power Flow Analysis for net 356
# Updating measurements of net 356
# Generating CLEAN scenario No. 357...
# Running Power Flow Analysis for net 357
# Updating measurements of net 357
# Generating CLEAN scenario No. 358...
# Running Power Flow Analysis for net 358
# Updating measurements of net 358
# Generating CLEAN scenario No. 359...
# Running Power Flow Analysis for net 359
# Updating measurements of net 359
# Generating CLEAN scenario No. 360...
# Running Power Flow Analysis for net 360
# Updating measurements of net 360
# Generating CLEAN scenario No. 361...
# Running Power Flow Analysis for net 361
# Updating measurements of net 361
# Generating CLEAN scenario No. 362...
# Running Power Flow Analysis for net 362
# Updating measurements of net 362
# Generating CLEAN scenario No. 363...
# Running Power Flow Analysis for net 363
# Updating measurements of net 363
# Generating CLEAN scenario No. 364...
# Running Power Flow Analysis for net 364
# Updating measurements of net 364
# Generating CLEAN scenario No. 365...
# Running Power Flow Analysis for net 365
# Updating measurements of net 365
# Generating CLEAN scenario No. 366...
# Running Power Flow Analysis for net 366
# Updating measurements of net 366
# Generating CLEAN scenario No. 367...
# Running Power Flow Analysis for net 367
# Updating measurements of net 367
# Generating CLEAN scenario No. 368...
# Running Power Flow Analysis for net 368
# Updating measurements of net 368
# Generating CLEAN scenario No. 369...
# Running Power Flow Analysis for net 369
# Updating measurements of net 369
# Generating CLEAN scenario No. 370...
# Running Power Flow Analysis for net 370
# Updating measurements of net 370
# Generating CLEAN scenario No. 371...
# Running Power Flow Analysis for net 371
# Updating measurements of net 371
# Generating CLEAN scenario No. 372...
# Running Power Flow Analysis for net 372
# Updating measurements of net 372
# Generating CLEAN scenario No. 373...
# Running Power Flow Analysis for net 373
# Updating measurements of net 373
# Generating CLEAN scenario No. 374...
# Running Power Flow Analysis for net 374
# Updating measurements of net 374
# Generating CLEAN scenario No. 375...
# Running Power Flow Analysis for net 375
# Updating measurements of net 375
# Generating CLEAN scenario No. 376...
# Running Power Flow Analysis for net 376
# Updating measurements of net 376
# Generating CLEAN scenario No. 377...
# Running Power Flow Analysis for net 377
# Updating measurements of net 377
# Generating CLEAN scenario No. 378...
# Running Power Flow Analysis for net 378
# Updating measurements of net 378
# Generating CLEAN scenario No. 379...
# Running Power Flow Analysis for net 379
# Updating measurements of net 379
# Generating CLEAN scenario No. 380...
# Running Power Flow Analysis for net 380
# Updating measurements of net 380
# Generating CLEAN scenario No. 381...
# Running Power Flow Analysis for net 381
# Updating measurements of net 381
# Generating CLEAN scenario No. 382...
# Running Power Flow Analysis for net 382
# Updating measurements of net 382
# Generating CLEAN scenario No. 383...
# Running Power Flow Analysis for net 383
# Updating measurements of net 383
# Generating CLEAN scenario No. 384...
# Running Power Flow Analysis for net 384
# Updating measurements of net 384
# Generating CLEAN scenario No. 385...
# Running Power Flow Analysis for net 385
# Updating measurements of net 385
# Generating CLEAN scenario No. 386...
# Running Power Flow Analysis for net 386
# Updating measurements of net 386
# Generating CLEAN scenario No. 387...
# Running Power Flow Analysis for net 387
# Updating measurements of net 387
# Generating CLEAN scenario No. 388...
# Running Power Flow Analysis for net 388
# Updating measurements of net 388
# Generating CLEAN scenario No. 389...
# Running Power Flow Analysis for net 389
# Updating measurements of net 389
# Generating CLEAN scenario No. 390...
# Running Power Flow Analysis for net 390
# Updating measurements of net 390
# Generating CLEAN scenario No. 391...
# Running Power Flow Analysis for net 391
# Updating measurements of net 391
# Generating CLEAN scenario No. 392...
# Running Power Flow Analysis for net 392
# Updating measurements of net 392
# Generating CLEAN scenario No. 393...
# Running Power Flow Analysis for net 393
# Updating measurements of net 393
# Generating CLEAN scenario No. 394...
# Running Power Flow Analysis for net 394
# Updating measurements of net 394
# Generating CLEAN scenario No. 395...
# Running Power Flow Analysis for net 395
# Updating measurements of net 395
# Generating CLEAN scenario No. 396...
# Running Power Flow Analysis for net 396
# Updating measurements of net 396
# Generating CLEAN scenario No. 397...
# Running Power Flow Analysis for net 397
# Updating measurements of net 397
# Generating CLEAN scenario No. 398...
# Running Power Flow Analysis for net 398
# Updating measurements of net 398
# Generating CLEAN scenario No. 399...
# Running Power Flow Analysis for net 399
# Updating measurements of net 399
# Generating CLEAN scenario No. 400...
# Running Power Flow Analysis for net 400
# Updating measurements of net 400
# Generating CLEAN scenario No. 401...
# Running Power Flow Analysis for net 401
# Updating measurements of net 401
# Generating CLEAN scenario No. 402...
# Running Power Flow Analysis for net 402
# Updating measurements of net 402
# Generating CLEAN scenario No. 403...
# Running Power Flow Analysis for net 403
# Updating measurements of net 403
# Generating CLEAN scenario No. 404...
# Running Power Flow Analysis for net 404
# Updating measurements of net 404
# Generating CLEAN scenario No. 405...
# Running Power Flow Analysis for net 405
# Updating measurements of net 405
# Generating CLEAN scenario No. 406...
# Running Power Flow Analysis for net 406
# Updating measurements of net 406
# Generating CLEAN scenario No. 407...
# Running Power Flow Analysis for net 407
# Updating measurements of net 407
# Generating CLEAN scenario No. 408...
# Running Power Flow Analysis for net 408
# Updating measurements of net 408
# Generating CLEAN scenario No. 409...
# Running Power Flow Analysis for net 409
# Updating measurements of net 409
# Generating CLEAN scenario No. 410...
# Running Power Flow Analysis for net 410
# Updating measurements of net 410
# Generating CLEAN scenario No. 411...
# Running Power Flow Analysis for net 411
# Updating measurements of net 411
# Generating CLEAN scenario No. 412...
# Running Power Flow Analysis for net 412
# Updating measurements of net 412
# Generating CLEAN scenario No. 413...
# Running Power Flow Analysis for net 413
# Updating measurements of net 413
# Generating CLEAN scenario No. 414...
# Running Power Flow Analysis for net 414
# Updating measurements of net 414
# Generating CLEAN scenario No. 415...
# Running Power Flow Analysis for net 415
# Updating measurements of net 415
# Generating CLEAN scenario No. 416...
# Running Power Flow Analysis for net 416
# Updating measurements of net 416
# Generating CLEAN scenario No. 417...
# Running Power Flow Analysis for net 417
# Updating measurements of net 417
# Generating CLEAN scenario No. 418...
# Running Power Flow Analysis for net 418
# Updating measurements of net 418
# Generating CLEAN scenario No. 419...
# Running Power Flow Analysis for net 419
# Updating measurements of net 419
# Generating CLEAN scenario No. 420...
# Running Power Flow Analysis for net 420
# Updating measurements of net 420
# Generating CLEAN scenario No. 421...
# Running Power Flow Analysis for net 421
# Updating measurements of net 421
# Generating CLEAN scenario No. 422...
# Running Power Flow Analysis for net 422
# Updating measurements of net 422
# Generating CLEAN scenario No. 423...
# Running Power Flow Analysis for net 423
# Updating measurements of net 423
# Generating CLEAN scenario No. 424...
# Running Power Flow Analysis for net 424
# Updating measurements of net 424
# Generating CLEAN scenario No. 425...
# Running Power Flow Analysis for net 425
# Updating measurements of net 425
# Generating CLEAN scenario No. 426...
# Running Power Flow Analysis for net 426
# Updating measurements of net 426
# Generating CLEAN scenario No. 427...
# Running Power Flow Analysis for net 427
# Updating measurements of net 427
# Generating CLEAN scenario No. 428...
# Running Power Flow Analysis for net 428
# Updating measurements of net 428
# Generating CLEAN scenario No. 429...
# Running Power Flow Analysis for net 429
# Updating measurements of net 429
# Generating CLEAN scenario No. 430...
# Running Power Flow Analysis for net 430
# Updating measurements of net 430
# Generating CLEAN scenario No. 431...
# Running Power Flow Analysis for net 431
# Updating measurements of net 431
# Generating CLEAN scenario No. 432...
# Running Power Flow Analysis for net 432
# Updating measurements of net 432
# Generating CLEAN scenario No. 433...
# Running Power Flow Analysis for net 433
# Updating measurements of net 433
# Generating CLEAN scenario No. 434...
# Running Power Flow Analysis for net 434
# Updating measurements of net 434
# Generating CLEAN scenario No. 435...
# Running Power Flow Analysis for net 435
# Updating measurements of net 435
# Generating CLEAN scenario No. 436...
# Running Power Flow Analysis for net 436
# Updating measurements of net 436
# Generating CLEAN scenario No. 437...
# Running Power Flow Analysis for net 437
# Updating measurements of net 437
# Generating CLEAN scenario No. 438...
# Running Power Flow Analysis for net 438
# Updating measurements of net 438
# Generating CLEAN scenario No. 439...
# Running Power Flow Analysis for net 439
# Updating measurements of net 439
# Generating CLEAN scenario No. 440...
# Running Power Flow Analysis for net 440
# Updating measurements of net 440
# Generating CLEAN scenario No. 441...
# Running Power Flow Analysis for net 441
# Updating measurements of net 441
# Generating CLEAN scenario No. 442...
# Running Power Flow Analysis for net 442
# Updating measurements of net 442
# Generating CLEAN scenario No. 443...
# Running Power Flow Analysis for net 443
# Updating measurements of net 443
# Generating CLEAN scenario No. 444...
# Running Power Flow Analysis for net 444
# Updating measurements of net 444
# Generating CLEAN scenario No. 445...
# Running Power Flow Analysis for net 445
# Updating measurements of net 445
# Generating CLEAN scenario No. 446...
# Running Power Flow Analysis for net 446
# Updating measurements of net 446
# Generating CLEAN scenario No. 447...
# Running Power Flow Analysis for net 447
# Updating measurements of net 447
# Generating CLEAN scenario No. 448...
# Running Power Flow Analysis for net 448
# Updating measurements of net 448
# Generating CLEAN scenario No. 449...
# Running Power Flow Analysis for net 449
# Updating measurements of net 449
# Generating CLEAN scenario No. 450...
# Running Power Flow Analysis for net 450
# Updating measurements of net 450
# Generating CLEAN scenario No. 451...
# Running Power Flow Analysis for net 451
# Updating measurements of net 451
# Generating CLEAN scenario No. 452...
# Running Power Flow Analysis for net 452
# Updating measurements of net 452
# Generating CLEAN scenario No. 453...
# Running Power Flow Analysis for net 453
# Updating measurements of net 453
# Generating CLEAN scenario No. 454...
# Running Power Flow Analysis for net 454
# Updating measurements of net 454
# Generating CLEAN scenario No. 455...
# Running Power Flow Analysis for net 455
# Updating measurements of net 455
# Generating CLEAN scenario No. 456...
# Running Power Flow Analysis for net 456
# Updating measurements of net 456
# Generating CLEAN scenario No. 457...
# Running Power Flow Analysis for net 457
# Updating measurements of net 457
# Generating CLEAN scenario No. 458...
# Running Power Flow Analysis for net 458
# Updating measurements of net 458
# Generating CLEAN scenario No. 459...
# Running Power Flow Analysis for net 459
# Updating measurements of net 459
# Generating CLEAN scenario No. 460...
# Running Power Flow Analysis for net 460
# Updating measurements of net 460
# Generating CLEAN scenario No. 461...
# Running Power Flow Analysis for net 461
# Updating measurements of net 461
# Generating CLEAN scenario No. 462...
# Running Power Flow Analysis for net 462
# Updating measurements of net 462
# Generating CLEAN scenario No. 463...
# Running Power Flow Analysis for net 463
# Updating measurements of net 463
# Generating CLEAN scenario No. 464...
# Running Power Flow Analysis for net 464
# Updating measurements of net 464
# Generating CLEAN scenario No. 465...
# Running Power Flow Analysis for net 465
# Updating measurements of net 465
# Generating CLEAN scenario No. 466...
# Running Power Flow Analysis for net 466
# Updating measurements of net 466
# Generating CLEAN scenario No. 467...
# Running Power Flow Analysis for net 467
# Updating measurements of net 467
# Generating CLEAN scenario No. 468...
# Running Power Flow Analysis for net 468
# Updating measurements of net 468
# Generating CLEAN scenario No. 469...
# Running Power Flow Analysis for net 469
# Updating measurements of net 469
# Generating CLEAN scenario No. 470...
# Running Power Flow Analysis for net 470
# Updating measurements of net 470
# Generating CLEAN scenario No. 471...
# Running Power Flow Analysis for net 471
# Updating measurements of net 471
# Generating CLEAN scenario No. 472...
# Running Power Flow Analysis for net 472
# Updating measurements of net 472
# Generating CLEAN scenario No. 473...
# Running Power Flow Analysis for net 473
# Updating measurements of net 473
# Generating CLEAN scenario No. 474...
# Running Power Flow Analysis for net 474
# Updating measurements of net 474
# Generating CLEAN scenario No. 475...
# Running Power Flow Analysis for net 475
# Updating measurements of net 475
# Generating CLEAN scenario No. 476...
# Running Power Flow Analysis for net 476
# Updating measurements of net 476
# Generating CLEAN scenario No. 477...
# Running Power Flow Analysis for net 477
# Updating measurements of net 477
# Generating CLEAN scenario No. 478...
# Running Power Flow Analysis for net 478
# Updating measurements of net 478
# Generating CLEAN scenario No. 479...
# Running Power Flow Analysis for net 479
# Updating measurements of net 479
# Generating CLEAN scenario No. 480...
# Running Power Flow Analysis for net 480
# Updating measurements of net 480
# Generating CLEAN scenario No. 481...
# Running Power Flow Analysis for net 481
# Updating measurements of net 481
# Generating CLEAN scenario No. 482...
# Running Power Flow Analysis for net 482
# Updating measurements of net 482
# Generating CLEAN scenario No. 483...
# Running Power Flow Analysis for net 483
# Updating measurements of net 483
# Generating CLEAN scenario No. 484...
# Running Power Flow Analysis for net 484
# Updating measurements of net 484
# Generating CLEAN scenario No. 485...
# Running Power Flow Analysis for net 485
# Updating measurements of net 485
# Generating CLEAN scenario No. 486...
# Running Power Flow Analysis for net 486
# Updating measurements of net 486
# Generating CLEAN scenario No. 487...
# Running Power Flow Analysis for net 487
# Updating measurements of net 487
# Generating CLEAN scenario No. 488...
# Running Power Flow Analysis for net 488
# Updating measurements of net 488
# Generating CLEAN scenario No. 489...
# Running Power Flow Analysis for net 489
# Updating measurements of net 489
# Generating CLEAN scenario No. 490...
# Running Power Flow Analysis for net 490
# Updating measurements of net 490
# Generating CLEAN scenario No. 491...
# Running Power Flow Analysis for net 491
# Updating measurements of net 491
# Generating CLEAN scenario No. 492...
# Running Power Flow Analysis for net 492
# Updating measurements of net 492
# Generating CLEAN scenario No. 493...
# Running Power Flow Analysis for net 493
# Updating measurements of net 493
# Generating CLEAN scenario No. 494...
# Running Power Flow Analysis for net 494
# Updating measurements of net 494
# Generating CLEAN scenario No. 495...
# Running Power Flow Analysis for net 495
# Updating measurements of net 495
# Generating CLEAN scenario No. 496...
# Running Power Flow Analysis for net 496
# Updating measurements of net 496
# Generating CLEAN scenario No. 497...
# Running Power Flow Analysis for net 497
# Updating measurements of net 497
# Generating CLEAN scenario No. 498...
# Running Power Flow Analysis for net 498
# Updating measurements of net 498
# Generating CLEAN scenario No. 499...
# Running Power Flow Analysis for net 499
# Updating measurements of net 499
#
#
# Duplicating each input (usually clean) scenario 10 times...

# %% [markdown]
# #### Convert clean scenarios to featured Measurments dataset

# %%
"""Generate meas features for clean scenarios (same functions are used for both ac and dc since meas piker will decide what measurements) """
source_clean_meas = meas2features(clean_scenarios_ids,clean_scenarios ) #make sure to add this right after duplicate scenarios before being impacted by adding noise
dplct_source_clean_meas = meas2features(dplct_ids,dplct_clean_scenarios ) #make sure to add this right after duplicate scenarios before being impacted by adding noise
dplct_source_clean_meas.to_csv(datasets_path + 'source_clean_meas.csv', index=False)
# Out:
# Convert measurements to features..
# Done!
# Convert measurements to features..
# Done!

# %% [markdown]
# #### Convert clean scenarios to featured States dataset

# %%
""" Generate states features both pfa-based and wls-based states for Clean scenarios"""
dplct_target_clean_states=pf_states2features(dplct_ids, dplct_clean_scenarios) #this is duplicated GT for ac
dplct_target_clean_states=dplct_target_clean_states.drop(columns=['va_'+str(slack)],axis=1)
dplct_target_clean_states.to_csv(datasets_path + 'target_gt_states.csv', index=False)
# Out:
# Convert estimated states to features..
# Done!

# %% [markdown]
# ## Add noise to clean scenarios

# %%
""" Generate Noisy  Scenarios"""
noisy_scenarios_ids,noisy_scenarios = gen_noisy_meas(input_params,dplct_ids,dplct_clean_scenarios) #Note: noise passed thru run_hp either gaussian or uniform. Note2:  changes made by this line will impact dplct_clean_scenarios since both  noisy_scenarios and dplct_clean_scenarios point to same objects
source_noisy_meas = meas2features(noisy_scenarios_ids,noisy_scenarios) #make sure to add this right after duplicate scenarios before being impacted by adding noise
source_noisy_meas.to_csv(datasets_path + 'source_noisy_meas.csv', index=False)
# Out:
# Add noise to measurements..
# Convert measurements to features..
# Done!
